# %% [markdown]
# ### General Text
# Bold: $\textbf{This is bold}$
#
# ### General Math
# Times symbol: $2 \times 2 = 4$ \
# Not equal sign: $ 4 \neq 3 $
#
# ### Matrices
#
# Vector length $ \|v\| $
#
# Matrix multiplication
#
# $$
#
# \begin{bmatrix}
# 3 \\
# 1 \\
# 2 \\
# \end{bmatrix}
# \begin{bmatrix}
# 2 & 4 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 6 & 12 \\
# 2 &  4 \\
# 4 &  8 \\
# \end{bmatrix}
#
# $$
#
# Text in matrix entries
# $$
# \begin{bmatrix}
# \text{m rows}    \\
# \text{n columns} \\
# \end{bmatrix}
# $$
