# %% [markdown]
# ### Matrices
#
# Vector length $ \|v\| $
#
# Times symbol $(m \times n )$
#
# Matrix multiplication
#
# $$
#
# \begin{bmatrix}
# 3 \\
# 1 \\
# 2 \\
# \end{bmatrix}
# \begin{bmatrix}
# 2 & 4 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 6 & 12 \\
# 2 &  4 \\
# 4 &  8 \\
# \end{bmatrix}
#
# $$
#
# Text in matrix entries
# $$
# \begin{bmatrix}
# \text{m rows}    \\
# \text{n columns} \\
# \end{bmatrix}
# $$
